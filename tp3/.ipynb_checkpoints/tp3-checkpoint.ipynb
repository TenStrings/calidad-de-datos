# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from scipy import stats
import matplotlib.patches as mpatches

#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')

#df =  pd.read_csv("Covid19Casos.csv", encoding='utf-16',parse_dates=["fecha_inicio_sintomas","fecha_internacion"],date_parser=dateparse)
df =  pd.read_csv("Covid19Casos.csv", encoding='utf-16')
numerical = [
    "edad", "sepi_apertura"
]

#categorical = ["sexo","edad_años_meses","residencia_pais_nombre","resicidencia_provincia_nombre","residencia_departamento_nombre",
#              "carga_provincia_nombre","fecha_inicio_sintomas","fecha_apertura","fecha_internacion","cuidado_intensivo","fecha_cui_intensivo",
#               "fallecido","fecha_fallecimiento","asistenia_respiratoria_mecanica","carga_provincia_id","origen_financiamento",
#               "Clasificacion","clasificacion_resumen","residencia_provincia_id","fecha_diagnostico","residencia_departamento_id","ultima_actualizacion"]
#print(df.dtypes)

df_var_numericas=df[numerical]
df_var_categoricas=df[filter(lambda column:not(column=="edad" or column=="sepi_apertura")  , df.columns)].astype("category")

# %%
def filter_row_by_two_cells_value(df,condition1,condition2):
    
    subsetDataFrame2 = df[(condition1(df) )& (condition2(df) )]
    return subsetDataFrame2

def count_string_in_column(df,column_name,string):
    df2=df[df[column_name]==string]   
    return df2[column_name].count()

def count_string_in_column_null(df,column_name,string):
    df2=df[(df[column_name]==string) | (df[column_name]=="")]   
    return df2[column_name].count()

# %%
df_var_numericas.describe()
# Out:
#                 edad  sepi_apertura
# count  185247.000000  185564.000000
# mean       40.784553      19.746179
# std        22.367641       3.087021
# min         0.000000       5.000000
# 25%        26.000000      17.000000
# 50%        38.000000      20.000000
# 75%        55.000000      22.000000
# max       120.000000      44.000000

# %%
df_var_categoricas.describe()
# Out:
#         id_evento_caso    sexo edad_años_meses residencia_pais_nombre  \
# count           185564  185564          185564                 185564
# unique          185564       3               2                     20
# top            1047756       F            Años              Argentina
# freq                 1   93209          182192                 178122
#
#        residencia_provincia_nombre residencia_departamento_nombre  \
# count                       185564                         185564
# unique                          25                            429
# top                   Buenos Aires                SIN ESPECIFICAR
# freq                         76818                          31254
#
#        carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  \
# count                  185564                123389         185563
# unique                     24                   143            108
# top                      CABA            2020-06-01     2020-06-08
# freq                    61954                  2894           5333
#
#        fecha_internacion  ... fecha_fallecimiento  \
# count              50015  ...                2202
# unique               118  ...                  93
# top           2020-05-20  ...          2020-04-27
# freq                 902  ...                  46
#
#        asistencia_respiratoria_mecanica carga_provincia_id  \
# count                            185564             185564
# unique                                2                 24
# top                                  NO                  2
# freq                             182678              61954
#
#        origen_financiamiento    Clasificacion  clasificacion_resumen  \
# count                 185564           185564                 185564
# unique                     2               14                      4
# top                  Público  Caso Descartado             Descartado
# freq                  114840           147146                 147917
#
#        residencia_provincia_id fecha_diagnostico residencia_departamento_id  \
# count                   185564            171856                     185564
# unique                      25               104                        154
# top                          6        2020-05-29                          0
# freq                     76818              4471                      31254
#
#         ultima_actualizacion
# count                 185564
# unique                     1
# top               2020-06-09
# freq                  185564
#
# [4 rows x 23 columns]

# %%
#datos faltantes o nulos cuando corresponde (completitud)
for column in df.columns:
    print(column, df[column].isna().sum())
# Out:
# id_evento_caso 0
# sexo 0
# edad 317
# edad_años_meses 0
# residencia_pais_nombre 0
# residencia_provincia_nombre 0
# residencia_departamento_nombre 0
# carga_provincia_nombre 0
# fecha_inicio_sintomas 62175
# fecha_apertura 1
# sepi_apertura 0
# fecha_internacion 135549
# cuidado_intensivo 0
# fecha_cui_intensivo 178086
# fallecido 0
# fecha_fallecimiento 183362
# asistencia_respiratoria_mecanica 0
# carga_provincia_id 0
# origen_financiamiento 0
# Clasificacion 0
# clasificacion_resumen 0
# residencia_provincia_id 0
# fecha_diagnostico 13708
# residencia_departamento_id 0
# ultima_actualizacion 0

# %%
#bivariado cuidado intensivo -  fecha cuidado intensivo (consistencia/completitud)
sub_df=df[["cuidado_intensivo","fecha_cui_intensivo"]]
subsetDataFrame = filter_row_by_two_cells_value(sub_df,lambda df:df['cuidado_intensivo'] == 'NO',lambda df:df['fecha_cui_intensivo'].notna() )

print("cantidad de no cuidado intensivo con fecha de cuidado intensivo ",subsetDataFrame.count() )#cantidad de no cuidado intensivo con fecha de cuidado intensivo


subsetDataFrame2 = sub_df[(sub_df['cuidado_intensivo'] == 'SI' )& (sub_df['fecha_cui_intensivo'].isna() )]
print("cantidad de cuidado intensivo sin fecha de cuidado intensivo ",subsetDataFrame2.count() )#cantidad de no cuidado intensivo con fecha de cuidado intensivo
# Out:
# cantidad de no cuidado intensivo con fecha de cuidado intensivo  cuidado_intensivo      52
# fecha_cui_intensivo    52
# dtype: int64
# cantidad de cuidado intensivo sin fecha de cuidado intensivo  cuidado_intensivo      0
# fecha_cui_intensivo    0
# dtype: int64

# %%
#bivariado fallecido - fecha fallecimiento (consistencia/completitu)
sub_df=df[['fallecido',"fecha_fallecimiento"]]
subsetDataFrame= filter_row_by_two_cells_value(sub_df,lambda df:df['fallecido'] == 'NO',lambda df:df['fecha_fallecimiento'].notna() )

print("no fallecidos con fecha de fallecimiento ",subsetDataFrame.count() )

subsetDataFrame= filter_row_by_two_cells_value(sub_df,lambda df:df['fallecido'] == 'SI',lambda df:df['fecha_fallecimiento'].isna() )

print("fallecidos sin fecha de fallecimiento ",subsetDataFrame.count() )



#subsetDataFrame= sub_df[['fallecido'] == 'SI']
#print("total fallecidos ",subsetDataFrame.count() )
# Out:
# no fallecidos con fecha de fallecimiento  fallecido              0
# fecha_fallecimiento    0
# dtype: int64
# fallecidos sin fecha de fallecimiento  fallecido              0
# fecha_fallecimiento    0
# dtype: int64

# %%
#contar la cantidad de valor "sin especificar" (completitud)


print("faltantes residencia_provincia_nombre",count_string_in_column_null(df,"residencia_provincia_nombre","SIN ESPECIFICAR"))

print("faltantes residencia_departamento_nombre" ,count_string_in_column_null(df,"residencia_departamento_nombre","SIN ESPECIFICAR"))

print("faltantes residencia_pais_nombre" ,count_string_in_column_null(df,"residencia_pais_nombre","SIN ESPECIFICAR"))

print("paises extranjeros que no especifican prov",df[( df['residencia_pais_nombre']!="Argentina" )&( df['residencia_pais_nombre']!="SIN ESPECIFICAR" )&(df["residencia_departamento_nombre"]=="SIN ESPECIFICAR")].shape[0])

print("caba sin especificar comuna",df[(  df['residencia_departamento_nombre']=="SIN ESPECIFICAR" )&(df["residencia_provincia_nombre"]=="CABA")].shape[0])
print("caba especifico comuna",df[(  df['residencia_departamento_nombre']!="SIN ESPECIFICAR" )&(df["residencia_provincia_nombre"]=="CABA")].shape[0])
# Out:
# faltantes residencia_provincia_nombre 690
# faltantes residencia_departamento_nombre 31254
# faltantes residencia_pais_nombre 7357
# paises extranjeros que no especifican prov 65
# caba sin especificar comuna 30057
# caba especifico comuna 15189

# %%
#analisis descriptivo bivariado cat-cat
#cross table clasificacion-clasificacion resumen (consistencia)
pd.crosstab(df["Clasificacion"],df["clasificacion_resumen"])
# Out:
# clasificacion_resumen                               Confirmado  Descartado  \
# Clasificacion
# Caso Descartado                                              0      147146
# Caso Invalidado Epidemiologicamente                          0         590
# Caso Sospechoso - Muestra no apta                            0           0
# Caso Sospechoso - Sin muestra                                0           0
# Caso confirmado - Activo                                 12216           0
# Caso confirmado - Activo Internado                        7018           0
# Caso confirmado - Activo con seguimiento negativo           16           0
# Caso confirmado - Fallecido                                717           0
# Caso confirmado - No Activo por criterio de lab...        2554           0
# Caso confirmado - No activo (por laboratorio y ...        1630           0
# Caso confirmado - No activo (por tiempo de evol...         597           0
# Caso sospechoso - Con muestra sin resultado                  0           0
# Otro diagnostico                                             0         181
# Sin clasificar                                               0           0
#
# clasificacion_resumen                               Sin Clasificar  Sospechoso
# Clasificacion
# Caso Descartado                                                  0           0
# Caso Invalidado Epidemiologicamente                              0           0
# Caso Sospechoso - Muestra no apta                                0         419
# Caso Sospechoso - Sin muestra                                    0        3594
# Caso confirmado - Activo                                         0           0
# Caso confirmado - Activo Internado                               0           0
# Caso confirmado - Activo con seguimiento negativo                0           0
# Caso confirmado - Fallecido                                      0           0
# Caso confirmado - No Activo por criterio de lab...               0           0
# Caso confirmado - No activo (por laboratorio y ...               0           0
# Caso confirmado - No activo (por tiempo de evol...               0           0
# Caso sospechoso - Con muestra sin resultado                      0        8882
# Otro diagnostico                                                 0           0
# Sin clasificar                                                   4           0

# %%
#catidad de dias transcurridos entre inicio sintomas e internacion
#fecha_internacion
#fecha_inicio_sintomas
#date_time_obj = datetime.strptime(date_time_str, '%d/%m/%y %H:%M:%S')

#df2=pd.to_datetime(df[["fecha_inicio_sintomas","fecha_internacion"]],format='%Y-%m-%d')
#df["intervalo"]=df["fecha_inicio_sintomas"]-df["fecha_internacion"]
#df[["fecha_inicio_sintomas","fecha_internacion"]].dtypes
dt.timedelta(7)
df['fecha_inicio_sintomas'] =  pd.to_datetime(df['fecha_inicio_sintomas'], format='%Y-%m-%d')
df['fecha_internacion'] =  pd.to_datetime(df['fecha_internacion'], format='%Y-%m-%d')
df['fecha_diagnostico'] =  pd.to_datetime(df['fecha_diagnostico'], format='%Y-%m-%d')
df['fecha_cui_intensivo'] =  pd.to_datetime(df['fecha_cui_intensivo'], format='%Y-%m-%d')
df2 = (df['fecha_diagnostico']-df['fecha_internacion']).dt.days
df2.describe()
#df["fecha_inicio_sintomas"]
df3 = (df['fecha_cui_intensivo']-df['fecha_internacion']).dt.days
df3.describe()
# Out:
# count    7369.000000
# mean        0.415796
# std         2.362908
# min       -56.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        90.000000
# dtype: float64

# %%
#analisis bivariado

con_edad = df[df['edad'].notna()]
edad_fallecidos = con_edad.loc[(con_edad['fallecido'] == 'SI') & (con_edad['edad_años_meses'] == 'Años'), :]

# split in bins of 10 years each
bins = np.arange(0, 110, 10)
out = pd.cut(edad_fallecidos['edad'], bins=bins, include_lowest=True)

ax = out.value_counts(sort=False).plot.bar(rot=0, color="b", figsize=(12,8))
ax.grid(axis='y', alpha=0.5, color='red', linestyle='--', linewidth=2)
ax.set_title('#Fallecidos por edad')
plt.xlabel("edad")
plt.ylabel("cantidad")
plt.show()

# %%
#analisis bivariado

pd.crosstab(df["origen_financiamiento"],df["fallecido"])
# Out:
# fallecido                  NO    SI
# origen_financiamiento
# Privado                 69749   975
# Público                113613  1227

# %%
df2=df[df["clasificacion_resumen"]=='Confirmado']   
con_edad = df2[df2['edad'].notna()]
con_edad[["edad","sepi_apertura"]].plot.scatter(x='sepi_apertura',y='edad')
#print(con_edad)
#df2["sepi_apertura"].plot.scatter(x=range(0,25),y='sepi_apertura')
#scipy.stats.pearsonr(con_edad["edad"].values, con_edad["sepi_apertura"].values)

# %%
pd.crosstab(df["residencia_provincia_nombre"],df["clasificacion_resumen"])
# Out:
# clasificacion_resumen        Confirmado  Descartado  Sin Clasificar  \
# residencia_provincia_nombre
# Buenos Aires                       9560       60560               0
# CABA                              11829       29874               1
# Catamarca                             0         427               0
# Chaco                              1118        6330               0
# Chubut                               27         491               0
# Corrientes                           98        2686               0
# Córdoba                             466       14342               1
# Entre Ríos                           56        1367               0
# Formosa                               0         702               0
# Jujuy                                10        2020               1
# La Pampa                              5         253               0
# La Rioja                             64        1283               1
# Mendoza                             102        1958               0
# Misiones                             36        1125               0
# Neuquén                             157        1446               0
# Río Negro                           490        2082               0
# SIN ESPECIFICAR                     164         455               0
# Salta                                17         668               0
# San Juan                              5         676               0
# San Luis                             11         367               0
# Santa Cruz                           49         469               0
# Santa Fe                            278        9989               0
# Santiago del Estero                  22        1689               0
# Tierra del Fuego                    136        1386               0
# Tucumán                              48        5272               0
#
# clasificacion_resumen        Sospechoso
# residencia_provincia_nombre
# Buenos Aires                       6698
# CABA                               3542
# Catamarca                             6
# Chaco                               552
# Chubut                               44
# Corrientes                          139
# Córdoba                             780
# Entre Ríos                           61
# Formosa                              33
# Jujuy                                85
# La Pampa                              5
# La Rioja                             45
# Mendoza                              85
# Misiones                             19
# Neuquén                              39
# Río Negro                            46
# SIN ESPECIFICAR                      71
# Salta                                34
# San Juan                             15
# San Luis                             19
# Santa Cruz                           24
# Santa Fe                            274
# Santiago del Estero                  85
# Tierra del Fuego                     20
# Tucumán                             174

# %%
df2=df[df["clasificacion_resumen"]=='Confirmado'] 
df3=df2.groupby(['sepi_apertura']).size().to_frame("size").reset_index()
print(df3.columns)
df3.plot.scatter(x='sepi_apertura',y='size')
# Out:
# Index(['sepi_apertura', 'size'], dtype='object')

# %%
pd.crosstab(df["residencia_provincia_nombre"],df["residencia_provincia_id"])
# Out:
# residencia_provincia_id         2      6    10     14    18    22   26    30  \
# residencia_provincia_nombre
# Buenos Aires                     0  76818    0      0     0     0    0     0
# CABA                         45246      0    0      0     0     0    0     0
# Catamarca                        0      0  433      0     0     0    0     0
# Chaco                            0      0    0      0     0  8000    0     0
# Chubut                           0      0    0      0     0     0  562     0
# Corrientes                       0      0    0      0  2923     0    0     0
# Córdoba                          0      0    0  15589     0     0    0     0
# Entre Ríos                       0      0    0      0     0     0    0  1484
# Formosa                          0      0    0      0     0     0    0     0
# Jujuy                            0      0    0      0     0     0    0     0
# La Pampa                         0      0    0      0     0     0    0     0
# La Rioja                         0      0    0      0     0     0    0     0
# Mendoza                          0      0    0      0     0     0    0     0
# Misiones                         0      0    0      0     0     0    0     0
# Neuquén                          0      0    0      0     0     0    0     0
# Río Negro                        0      0    0      0     0     0    0     0
# SIN ESPECIFICAR                  0      0    0      0     0     0    0     0
# Salta                            0      0    0      0     0     0    0     0
# San Juan                         0      0    0      0     0     0    0     0
# San Luis                         0      0    0      0     0     0    0     0
# Santa Cruz                       0      0    0      0     0     0    0     0
# Santa Fe                         0      0    0      0     0     0    0     0
# Santiago del Estero              0      0    0      0     0     0    0     0
# Tierra del Fuego                 0      0    0      0     0     0    0     0
# Tucumán                          0      0    0      0     0     0    0     0
#
# residencia_provincia_id       34    38  ...    62   66   70   74   78     82  \
# residencia_provincia_nombre             ...
# Buenos Aires                   0     0  ...     0    0    0    0    0      0
# CABA                           0     0  ...     0    0    0    0    0      0
# Catamarca                      0     0  ...     0    0    0    0    0      0
# Chaco                          0     0  ...     0    0    0    0    0      0
# Chubut                         0     0  ...     0    0    0    0    0      0
# Corrientes                     0     0  ...     0    0    0    0    0      0
# Córdoba                        0     0  ...     0    0    0    0    0      0
# Entre Ríos                     0     0  ...     0    0    0    0    0      0
# Formosa                      735     0  ...     0    0    0    0    0      0
# Jujuy                          0  2116  ...     0    0    0    0    0      0
# La Pampa                       0     0  ...     0    0    0    0    0      0
# La Rioja                       0     0  ...     0    0    0    0    0      0
# Mendoza                        0     0  ...     0    0    0    0    0      0
# Misiones                       0     0  ...     0    0    0    0    0      0
# Neuquén                        0     0  ...     0    0    0    0    0      0
# Río Negro                      0     0  ...  2618    0    0    0    0      0
# SIN ESPECIFICAR                0     0  ...     0    0    0    0    0      0
# Salta                          0     0  ...     0  719    0    0    0      0
# San Juan                       0     0  ...     0    0  696    0    0      0
# San Luis                       0     0  ...     0    0    0  397    0      0
# Santa Cruz                     0     0  ...     0    0    0    0  542      0
# Santa Fe                       0     0  ...     0    0    0    0    0  10541
# Santiago del Estero            0     0  ...     0    0    0    0    0      0
# Tierra del Fuego               0     0  ...     0    0    0    0    0      0
# Tucumán                        0     0  ...     0    0    0    0    0      0
#
# residencia_provincia_id        86    90    94   99
# residencia_provincia_nombre
# Buenos Aires                    0     0     0    0
# CABA                            0     0     0    0
# Catamarca                       0     0     0    0
# Chaco                           0     0     0    0
# Chubut                          0     0     0    0
# Corrientes                      0     0     0    0
# Córdoba                         0     0     0    0
# Entre Ríos                      0     0     0    0
# Formosa                         0     0     0    0
# Jujuy                           0     0     0    0
# La Pampa                        0     0     0    0
# La Rioja                        0     0     0    0
# Mendoza                         0     0     0    0
# Misiones                        0     0     0    0
# Neuquén                         0     0     0    0
# Río Negro                       0     0     0    0
# SIN ESPECIFICAR                 0     0     0  690
# Salta                           0     0     0    0
# San Juan                        0     0     0    0
# San Luis                        0     0     0    0
# Santa Cruz                      0     0     0    0
# Santa Fe                        0     0     0    0
# Santiago del Estero          1796     0     0    0
# Tierra del Fuego                0     0  1542    0
# Tucumán                         0  5494     0    0
#
# [25 rows x 25 columns]

# %%
columna = 'fecha_internacion'
confirmados = df[df['clasificacion_resumen'] == 'Confirmado']
data = confirmados.loc[confirmados[columna].notna(), [columna, 'sepi_apertura']].sort_values(by=columna).to_numpy().transpose()

def parse_date(fecha):
    return dt.datetime.strptime(str(fecha), '%Y-%m-%d %H:%M:%S')

fechas = data[0]
sepis = list(map(int, data[1]))

min_fecha = fechas.min()

def date_to_number(fecha):
    return dt.datetime.timestamp(parse_date(fecha))

fechas_num = [date_to_number(date) for date in fechas]

print(np.corrcoef([fechas_num, sepis]))

fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(fechas_num, sepis)

fechas_unique = np.unique(fechas)
fechas_num_unique = np.unique(fechas_num)

### Sliding window, filter days on the same day than the last used
i = 0
first_day_of_week = [i]
j = 1
while i < len(fechas_unique):
    while j < len(fechas_unique):
        if (fechas_unique[j] - fechas_unique[i]).days >= 7:
            i = j
            first_day_of_week.append(i)
        j = j + 1
    if j == len(fechas_unique):
        break
            
filtered = [fechas_unique[i] for i in first_day_of_week]
filtered_num = [fechas_num_unique[i] for i in first_day_of_week]

plt.xticks(filtered_num, [str(f.date())[5:] for f in filtered], rotation=90)
plt.yticks(np.unique(sepis))

plt.xlabel(columna)
plt.ylabel("sepi_apertura")

ax.set_title('Fecha de internación (casos confirmados) y semana de apertura')

plt.savefig("internacion_apertura.png")
plt.show()
